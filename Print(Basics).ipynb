# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhananjay0705/Python-Lecture/blob/main/Print(Basics).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Output**

# %%
## Python is a case sensitive Language
print("Hello World")
# Out:
# Hello World

# %%
print("salman Khan")
# Out:
# salman Khan

# %%
print(7)
# Out:
# 7

# %%
print(True)
# Out:
# True

# %%
print("HELLO",1,3.5,True)
# Out:
# HELLO 1 3.5 True

# %%
print("HELLO",1,3.5,True,sep="/")
# Out:
# HELLO/1/3.5/True

# %%
print("Hello",end="-")
print("Hello")
# Out:
# Hello-Hello

# %% [markdown]
# **DATA TYPES**

# %%
## Integer
print(8)
print(1e308)
# Out:
# 8
# 1e+308

# %%
## Decimal/Float
print(8.55)
print(1.7e308)
# Out:
# 8.55
# 1.7e+308

# %%
##Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
## Text/String
print('Hello world')
# Out:
# Hello world

# %%
##complex
print(5+6j)
# Out:
# (5+6j)

# %%
## List -> C -> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
## Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
## Set
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
  ## Dictionary
print({"NAME":"DHANANJAY","Gender":"Male","Age":"22"})
# Out:
# {'NAME': 'DHANANJAY', 'Gender': 'Male', 'Age': '22'}

# %%
## Type (It is function)
type((1,2,3))
# Out:
# tuple
