# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhananjay0705/Python-Lecture/blob/main/Variables%2Ckeywords%2Cidentifiers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **VARIABLES**

# %%
name = "Dhananjay"
print(name)
# Out:
# Dhananjay

# %%
a = 5
b = 6
print(a+b)
# Out:
# 11

# %%
## Dynamic Typing
a = 5
## Static Typing
a = 5

# %%
## Dynamic Binding ("Variable values are not fix")("IN PYTHON datatype can be change")
a = 5
print(a)
a = 'Dhananjay'
print(a)
# Out:
# 5
# Dhananjay

# %%
## Static Binding ("datatype fix , not changable")

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a = b = c = 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# **Comments**

# %%
## This is a comment
a = 4
b = 6
print(a+b)
# Out:
# 10

# %% [markdown]
# **Keyword & Identifiers**

# %%
## Keywords = 32 fix words by the python (ex- print,if,else etc.)

# %%
## Identifier
#Rule 1)- You can't start with a digit
name1 = "Dhananjay"
print(name1)
# Rule 2)- You can use special character -> _
first_name = "Dhananjay"
print(first_name)
# Rule 3) - Identifier can not be keywords
# Out:
# Dhananjay
# Dhananjay

# %% [markdown]
# **USER INPUT**

# %%
## take input from the user and store them in a variable
f1 = int(input("Enter the first number"))
f2 = int(input("Enter the second number"))
print(type(f1),type(f2))
## add 2 variable
result = f1+f2
## print the result
print(result)
# Out:
# Enter the first number55
# Enter the second number35
# <class 'int'> <class 'int'>
# 90

# %% [markdown]
# **Type Conversion**

# %%
## Implicit type conversion computer automatically kar deta hai
print(5+5.6)
print(type(5),type(5.6))
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
print(4 + float('12.4'))
# Out:
# 16.4

# %%
## Explicit
## str -> int
int(4)
## int --> str
str(5)
## int --> float
float(4)
# Out:
# 4.0

# %% [markdown]
# **Literals**

# %%
## Literals means variable ko jo value dete hai ussi ko literals kehte hai

# %% [markdown]
# **Strings**

# %%
string = 'This is Python'
strings = "This is Python"
strings_ = '''This is Python''' ## """"""for use whwn we write long string
unicode = u"\u2764"
print(string)
print(strings)
print(strings_)
print(unicode)
# Out:
# This is Python
# This is Python
# This is Python
# ❤

# %%
## Boolean
a = True + 4 ## True means 1
b = False + 10 ## False means 0
print("a :",a)
print("b :",b)
# Out:
# a : 5
# b : 10

# %%
k = None
a1 = 5
print(None)
# Out:
# None
